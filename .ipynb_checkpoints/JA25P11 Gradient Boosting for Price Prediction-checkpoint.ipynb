# %% [markdown]
# <h1><font color='#306998'><center>Extreme Gradient Boosting</center></font></h1>
# <h4><center>Python Implementation</center><h4>
# <center>Kannan Singaravelu, CQF</center>
#
# ---

# %% [markdown]
# ## Implementation
# We will use XGBClassifier from XGBoost library to predict future prices of the security by creating a custom list of features from the raw price series.

# %% [markdown]
# **Import Libraries**

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data manipulation 
import pandas as pd
import numpy as np

# Quant library
from quantmod.timeseries import *
from quantmod.indicators import *

# Plotting
import matplotlib.pyplot as plt

# Preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import (train_test_split, 
                                    RandomizedSearchCV, 
                                    TimeSeriesSplit, 
                                    )
# Classifier
import xgboost as xgb
from xgboost import XGBClassifier, plot_importance, to_graphviz

# metrics
from sklearn.metrics import (accuracy_score,
                             auc,
                             roc_curve, 
                             RocCurveDisplay,
                             ConfusionMatrixDisplay,
                             confusion_matrix
                            )


from sklearn.metrics import (classification_report, 
                             confusion_matrix 
                            )

# %% [markdown]
# ### Retrieve Data
# We will retrieve the adjusted closed price of SPY from locally stored data.

# %%
# Load file
df = pd.read_csv('https://raw.githubusercontent.com/kannansingaravelu/datasets/main/spy.csv', index_col=0, parse_dates=True, dayfirst=True)

# Calculate returns
df['Returns'] = dailyReturn(df['Adj Close'])

# Verify the output
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-12-31  146.843750  147.500000  146.250000  146.875000  100.376900
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   99.394493
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   95.507530
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   95.678391
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   94.140717
# ...                ...         ...         ...         ...         ...
# 2020-04-23  280.489990  283.940002  278.750000  279.079987  279.079987
# 2020-04-24  280.730011  283.700012  278.500000  282.970001  282.970001
# 2020-04-27  285.119995  288.269989  284.619995  287.049988  287.049988
# 2020-04-28  291.019989  291.399994  285.399994  285.730011  285.730011
# 2020-04-29  291.529999  294.880005  290.410004  293.209991  293.209991
#
#                Volume   Returns
# Date
# 1999-12-31    3172700       NaN
# 2000-01-03    8164300 -0.009835
# 2000-01-04    8089800 -0.039892
# 2000-01-05   12177900  0.001787
# 2000-01-06    6227200 -0.016202
# ...               ...       ...
# 2020-04-23  104709700 -0.000072
# 2020-04-24   85166000  0.013842
# 2020-04-27   77896600  0.014315
# 2020-04-28  105270000 -0.004609
# 2020-04-29  118745600  0.025842
#
# [5114 rows x 7 columns]

# %% [markdown]
# ### EDA of Original dataset

# %%
# Descriptive statistics
df.describe().T
# Out:
#             count          mean           std           min           25%  \
# Open       5114.0  1.598580e+02  6.067946e+01  6.795000e+01  1.157525e+02
# High       5114.0  1.607984e+02  6.083027e+01  7.000000e+01  1.166625e+02
# Low        5114.0  1.588300e+02  6.051593e+01  6.710000e+01  1.149025e+02
# Close      5114.0  1.598609e+02  6.069407e+01  6.811000e+01  1.158975e+02
# Adj Close  5114.0  1.363339e+02  6.792366e+01  5.418443e+01  8.741249e+01
# Volume     5114.0  1.127593e+08  9.870486e+07  1.436600e+06  4.821255e+07
# Returns    5113.0  2.096532e-04  1.255748e-02 -1.158865e-01 -4.648976e-03
#
#                     50%           75%           max
# Open       1.370850e+02  2.017675e+02  3.377900e+02
# High       1.379550e+02  2.027875e+02  3.390800e+02
# Low        1.361100e+02  2.007225e+02  3.374800e+02
# Close      1.369450e+02  2.018725e+02  3.383400e+02
# Adj Close  1.064888e+02  1.829516e+02  3.363621e+02
# Volume     8.357545e+07  1.515544e+08  8.710263e+08
# Returns    6.417692e-04  5.800776e-03  1.355774e-01

# %% [markdown]
# ### Cleaning & Imputation
#
# Data is already cleaned. However, NaN values from derived features should be treated.

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Returns      1
# dtype: int64

# %% [markdown]
# ### Feature Specification
# Features or Predictors are also known as an independent variable which are used to determine the value of the target variable. We will use raw price to derive list of custom features.

# %%
# use quantmod to use indicators
features_list = []
for r in range(5, 50 , 5):
    df['SMA_'+str(r)] = SMA(df['Adj Close'], r)
    df['EMA_'+str(r)] = EMA(df['Adj Close'], r)
    features_list.append('SMA_'+str(r))
    features_list.append('EMA_'+str(r))

df['ATR'] = ATR(df)
df['BBANDS_L'] = BBands(df['Adj Close'],5,2)[0]
df['BBANDS_M'] = BBands(df['Adj Close'],5,2)[1]
df['BBANDS_U'] = BBands(df['Adj Close'],5,2)[2]
df['RSI'] = RSI(df['Adj Close'], 14)
df['MACD'] = MACD(df['Adj Close'], 5, 12, 26)[0]

# Drop NaN values
df.dropna(inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-03-06  140.812500  141.343750  138.750000  139.750000   95.507530
# 2000-03-07  140.000000  140.156250  135.218750  137.046875   93.660210
# 2000-03-08  136.468750  137.843750  135.031250  136.875000   93.542732
# 2000-03-09  137.250000  140.875000  136.125000  140.875000   96.276367
# 2000-03-10  140.187500  142.000000  139.531250  140.125000   95.763870
# ...                ...         ...         ...         ...         ...
# 2020-04-23  280.489990  283.940002  278.750000  279.079987  279.079987
# 2020-04-24  280.730011  283.700012  278.500000  282.970001  282.970001
# 2020-04-27  285.119995  288.269989  284.619995  287.049988  287.049988
# 2020-04-28  291.019989  291.399994  285.399994  285.730011  285.730011
# 2020-04-29  291.529999  294.880005  290.410004  293.209991  293.209991
#
#                Volume   Returns       SMA_5       EMA_5      SMA_10  ...  \
# Date                                                                 ...
# 2000-03-06   11967100 -0.009791   95.033429   95.007774   93.633495  ...
# 2000-03-07   20062000 -0.019532   94.980046   94.558586   93.775521  ...
# 2000-03-08   11808500 -0.001255   94.766475   94.219968   93.796876  ...
# 2000-03-09    5500900  0.028805   95.086819   94.905434   94.279536  ...
# 2000-03-10    7924600 -0.005337   94.950142   95.191580   94.744048  ...
# ...               ...       ...         ...         ...         ...  ...
# 2020-04-23  104709700 -0.000072  279.890002  278.672024  279.396005  ...
# 2020-04-24   85166000  0.013842  279.156000  280.104683  279.873004  ...
# 2020-04-27   77896600  0.014315  280.247998  282.419785  281.012003  ...
# 2020-04-28  105270000 -0.004609  282.785999  283.523193  281.206003  ...
# 2020-04-29  118745600  0.025842  285.607996  286.752126  282.751001  ...
#
#                 SMA_40      EMA_40      SMA_45      EMA_45       ATR  \
# Date
# 2000-03-06   96.217661   95.852846   96.306766   96.085670  2.891741
# 2000-03-07   96.068965   95.745888   96.157506   95.980215  3.000000
# 2000-03-08   95.908789   95.638417   96.027467   95.874238  3.037946
# 2000-03-09   95.846855   95.669537   96.044552   95.891722  3.218750
# 2000-03-10   95.796668   95.674138   96.046452   95.886163  3.091518
# ...                ...         ...         ...         ...       ...
# 2020-04-23  268.434096  276.323438  274.331356  277.899923  8.602143
# 2020-04-24  268.114076  276.647660  273.175573  278.120361  8.395001
# 2020-04-27  267.927123  277.155091  272.187117  278.508606  7.428571
# 2020-04-28  267.388297  277.573380  271.413668  278.822580  7.130713
# 2020-04-29  267.256426  278.336141  271.022285  279.448120  7.007856
#
#               BBANDS_L    BBANDS_M    BBANDS_U        RSI      MACD
# Date
# 2000-03-06   93.095617   95.033429   96.971241  50.576360 -0.603398
# 2000-03-07   92.881788   94.980046   97.078304  41.164487 -0.626623
# 2000-03-08   92.295848   94.766475   97.237102  44.917778 -0.647050
# 2000-03-09   92.282852   95.086819   97.890787  55.361687 -0.437612
# 2000-03-10   92.424981   94.950142   97.475303  60.953175 -0.309419
# ...                ...         ...         ...        ...       ...
# 2020-04-23  270.058661  279.890002  289.721344  67.266486  2.598033
# 2020-04-24  271.547767  279.156000  286.764233  71.968147  3.009828
# 2020-04-27  269.840615  280.247998  290.655381  66.666651  3.623628
# 2020-04-28  275.423680  282.785999  290.148317  65.232179  3.957934
# 2020-04-29  275.145755  285.607996  296.070237  64.486397  4.771443
#
# [5070 rows x 31 columns]

# %%
# Convert to NumPy
X = df.drop(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Returns'],axis=1)
X.head(2)
# Out:
#               Volume      SMA_5      EMA_5     SMA_10     EMA_10     SMA_15  \
# Date
# 2000-03-06  11967100  95.033429  95.007774  93.633495  94.527836  94.004034
# 2000-03-07  20062000  94.980046  94.558586  93.775521  94.370086  93.892270
#
#                EMA_15     SMA_20     EMA_20     SMA_25  ...     SMA_40  \
# Date                                                    ...
# 2000-03-06  94.574757  94.703468  94.791962  95.099208  ...  96.217661
# 2000-03-07  94.460438  94.521402  94.684176  95.030441  ...  96.068965
#
#                EMA_40     SMA_45     EMA_45       ATR   BBANDS_L   BBANDS_M  \
# Date
# 2000-03-06  95.852846  96.306766  96.085670  2.891741  93.095617  95.033429
# 2000-03-07  95.745888  96.157506  95.980215  3.000000  92.881788  94.980046
#
#              BBANDS_U        RSI      MACD
# Date
# 2000-03-06  96.971241  50.576360 -0.603398
# 2000-03-07  97.078304  41.164487 -0.626623
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Target or Label Definition
#
# Label or the target variable is also known as the dependent variable. Here, the target variable is whether the underlying price will close up or down on the next trading day. If the tomorrow’s closing price is greater than 99.50% of today’s closing price, then we will buy the underlying, else do nothing.

# %%
# Define Target
df['Target'] = np.where(lead(df['Adj Close'])>0.995 * df['Adj Close'],1,0)  
df.head(2)
# Out:
#                 Open       High        Low       Close  Adj Close    Volume  \
# Date
# 2000-03-06  140.8125  141.34375  138.75000  139.750000   95.50753  11967100
# 2000-03-07  140.0000  140.15625  135.21875  137.046875   93.66021  20062000
#
#              Returns      SMA_5      EMA_5     SMA_10  ...     EMA_40  \
# Date                                                   ...
# 2000-03-06 -0.009791  95.033429  95.007774  93.633495  ...  95.852846
# 2000-03-07 -0.019532  94.980046  94.558586  93.775521  ...  95.745888
#
#                SMA_45     EMA_45       ATR   BBANDS_L   BBANDS_M   BBANDS_U  \
# Date
# 2000-03-06  96.306766  96.085670  2.891741  93.095617  95.033429  96.971241
# 2000-03-07  96.157506  95.980215  3.000000  92.881788  94.980046  97.078304
#
#                   RSI      MACD  Target
# Date
# 2000-03-06  50.576360 -0.603398       0
# 2000-03-07  41.164487 -0.626623       1
#
# [2 rows x 32 columns]

# %%
# Define label or target 
y = df['Target']
y
# Out:
# Date
# 2000-03-06    0
# 2000-03-07    1
# 2000-03-08    1
# 2000-03-09    0
# 2000-03-10    0
#              ..
# 2020-04-23    1
# 2020-04-24    1
# 2020-04-27    1
# 2020-04-28    1
# 2020-04-29    0
# Name: Target, Length: 5070, dtype: int64

# %% [markdown]
# **Split Data**

# %%
# Splitting the datasets into training and testing data.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Output the train and test data size
print(f"Train and Test Size {len(X_train)}, {len(X_test)}")
# Out:
# Train and Test Size 4056, 1014

# %% [markdown]
# **Feature Scaling**

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# **Class Weights**

# %%
# class weight function
def cwts(dfs):
    c0, c1 = np.bincount(dfs)
    w0=(1/c0)*(len(df))/2 
    w1=(1/c1)*(len(df))/2 
    return {0: w0, 1: w1}

# %% [markdown]
# **DMatrix**

# %%
# Use DMatrix from XGBoost
train_weights = [cwts(y_train)[0] if label == 0 else cwts(y_train)[1] for label in y_train]
dtrain = xgb.DMatrix(X_train_scaled, label=y_train, nthread=4, weight=train_weights, feature_names=X_train.columns.to_list())

test_weights = [cwts(y_test)[0] if label == 0 else cwts(y_test)[1] for label in y_test]
dtest = xgb.DMatrix(X_test_scaled, label=y_test, nthread=4, weight=test_weights, feature_names=X_test.columns.to_list())

# %% [markdown]
# ## Base Model

# %% [markdown]
# We will now create and train the XGBoost (Regessor). All the feature and label should have a similar scale and the scaling can be accomplished by using the `StandardScaler` transformer.

# %% [markdown]
# ### Fit Model

# %%
# specify params
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': 3,
    'eta': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8
}

# train the model
base_model = xgb.train(
    params, 
    dtrain, 
    num_boost_round=100,
    evals=[(dtrain, 'train'), (dtest, 'eval')],
    # early_stopping_rounds=20,
    # verbose_eval=20
    )
# Out:
# [0]	train-logloss:0.68690	eval-logloss:0.69006
# [1]	train-logloss:0.68198	eval-logloss:0.68762
# [2]	train-logloss:0.67814	eval-logloss:0.68609
# [3]	train-logloss:0.67456	eval-logloss:0.67758
# [4]	train-logloss:0.67146	eval-logloss:0.67552
# [5]	train-logloss:0.66867	eval-logloss:0.67227
# [6]	train-logloss:0.66639	eval-logloss:0.67114
# [61]	train-logloss:0.61790	eval-logloss:0.72627
# [62]	train-logloss:0.61728	eval-logloss:0.72702
# [63]	train-logloss:0.61680	eval-logloss:0.72718
# [64]	train-logloss:0.61604	eval-logloss:0.72671
# [65]	train-logloss:0.61535	eval-logloss:0.72602
# [66]	train-logloss:0.61466	eval-logloss:0.72742
# [67]	train-logloss:0.61398	eval-logloss:0.72684
# [68]	train-logloss:0.61294	eval-logloss:0.72834
# [69]	train-logloss:0.61229	eval-logloss:0.72844
# [70]	train-logloss:0.61166	eval-logloss:0.72762
# [71]	train-logloss:0.61100	eval-logloss:0.72784
# [72]	train-logloss:0.61050	eval-logloss:0.72834
# [73]	train-logloss:0.60999	eval-logloss:0.72847
# [74]	train-logloss:0.60908	eval-logloss:0.73278
# [75]	train-logloss:0.60843	eval-logloss:0.73178
# [76]	train-logloss:0.60794	eval-logloss:0.74252
# [77]	train-logloss:0.60706	eval-logloss:0.74376
# [78]	train-logloss:0.60684	eval-logloss:0.74743
# [79]	train-logloss:0.60586	eval-logloss:0.74812
# [80]	train-logloss:0.60543	eval-logloss:0.74782
# [81]	train-logloss:0.60513	eval-logloss:0.74389
# [82]	train-logloss:0.60442	eval-logloss:0.74459
# [83]	train-logloss:0.60420	eval-logloss:0.74452
# [84]	train-logloss:0.60368	eval-logloss:0.74438
# [85]	train-logloss:0.60315	eval-logloss:0.74341
# [86]	train-logloss:0.60272	eval-logloss:0.73691
# [87]	train-logloss:0.60196	eval-logloss:0.74006
# [88]	train-logloss:0.60159	eval-logloss:0.74388
# [89]	train-logloss:0.60096	eval-logloss:0.74354
# [90]	train-logloss:0.60044	eval-logloss:0.74329
# [91]	train-logloss:0.59985	eval-logloss:0.74188
# [92]	train-logloss:0.59940	eval-logloss:0.74230
# [93]	train-logloss:0.59873	eval-logloss:0.74240
# [94]	train-logloss:0.59796	eval-logloss:0.74031
# [95]	train-logloss:0.59772	eval-logloss:0.74066
# [96]	train-logloss:0.59682	eval-logloss:0.74127
# [97]	train-logloss:0.59633	eval-logloss:0.74116
# [98]	train-logloss:0.59598	eval-logloss:0.74038
# [99]	train-logloss:0.59527	eval-logloss:0.74272

# %% [markdown]
# ### Predict Model

# %%
# get probabilities 
y_proba = base_model.predict(dtest)
# get predictions
y_pred = np.round(y_proba)

# %%
# Confusion Matrix - Base Model
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down (0)', 'Up (1)'])
disp.plot(cmap='Blues')
plt.title('Base Model Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
# Classification report - Base Model
print(f"\n Base Model Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#  Base Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.19      0.86      0.31       170
#            1       0.90      0.23      0.37       844
#
#     accuracy                           0.34      1014
#    macro avg       0.54      0.55      0.34      1014
# weighted avg       0.78      0.34      0.36      1014

# %%
# ROC Curve - Base Model
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

disp = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
disp.plot()

plt.title('Base Model ROC Curve')
plt.plot([0, 1], [0, 1], color='orange', lw=2, linestyle='--')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Calculate training accuracy
train_preds = np.round(base_model.predict(dtrain))
train_accuracy = accuracy_score(y_train, train_preds)

# Calculate test accuracy
test_preds = np.round(base_model.predict(dtest))
test_accuracy = accuracy_score(y_test, test_preds)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Difference (Training - Test): {train_accuracy - test_accuracy:.4f}")
# Out:
# Training Accuracy: 0.6935
# Test Accuracy: 0.3402
# Difference (Training - Test): 0.3533

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# Hyper-parameters are parameters that are not directly learnt within estimators. They are passed as arguments to the constructor of the estimator classes (Classifier in this case). It is possible and recommended to search the hyper-parameter space for the best cross validation score. Any parameter provided when constructing an estimator may be optimized in this manner.
#
# We will tune the hyperparameters to select the best score by TimeSeriesSplit cross-validation. This is a variation of KFold. In the kth split, it returns first k folds as train set and the (k+1)th fold as test set. Unlike standard cross-validation methods, successive training sets are supersets of those that come before them.
#
# ### XGBoost's hyper-parameter
# XGBoost has plethora of tuning parameters includeing the regulatization parameters and some of the most common hyperparameters are:
#
# * `learning rate`: step size shrinkage used in update to prevents overfitting. Range is [0,1].
# * `max_depth`: maximum depth of a tree.
# * `colsample_bytree`: percentage of features used per tree. High value can lead to overfitting.
# * `min_child_weight`: minimum sum of instance weight needed in a child.
# * `gamma`: minimum loss reduction required to make a further partition on a leaf node of the tree. Large gamma will lead to more conservative algorithm.
# * `lambda`: L2 regularization term on weights. Increasing this value will make model more conservative. Normalised to number of training examples. [parameter for linear booster].
#
# Refer [here](https://xgboost.readthedocs.io/en/latest/parameter.html#general-parameters) for complete list of tuning parameters.

# %% [markdown]
# ### RandomizedSearch
# The RandomizedSearchCV implements a “fit” and a “score” method and perform randomized search on hyper parameters. The parameters of the estimator used to apply these methods are optimized by cross-validated search over parameter settings. In contrast to GridSearchCV, not all parameter values are tried out, but rather a fixed number of parameter settings is sampled from the specified distributions.

# %%
# Create XGBoost classifier for sklearn API
xgb_classifier = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
)

# %%
# Cross-validation
tscv = TimeSeriesSplit(n_splits=5, gap=1)

# %%
# Hyperparameter grid
param_grid = {
    'max_depth': [3, 4, 5, 6, 7],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2, 0.3],
    'min_child_weight': [1, 3, 5, 7]
}

# %%
# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=xgb_classifier,
    param_distributions=param_grid,
    n_iter=100,
    scoring='roc_auc',
    cv=tscv,
    verbose=1,
    n_jobs=-1
)

# %%
# Fit RandomizedSearchCV
random_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=1, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=Non...
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None, ...),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.7, 0.8,
#                                                              0.9],
#                                         'gamma': [0, 0.1, 0.2, 0.3],
#                                         'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                                         'max_depth': [3, 4, 5, 6, 7],
#                                         'min_child_weight': [1, 3, 5, 7],
#                                         'n_estimators': [50, 100, 200, 300],
#                                         'subsample': [0.6, 0.7, 0.8, 0.9]},
#                    scoring='roc_auc', verbose=1)

# %%
# Print best parameters
print("\nBest parameters found by RandomizedSearchCV:")
print(random_search.best_params_)
print(f"Best score: {random_search.best_score_:.4f}")
# Out:
# Best parameters found by RandomizedSearchCV:
# {'subsample': 0.6, 'n_estimators': 100, 'min_child_weight': 7, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0.3, 'colsample_bytree': 0.8}
# Best score: 0.5977

# %% [markdown]
# ## Optimized Model
# Let's now train and predict the model with the best search parameter

# %%
# Train optimized model with XGBoost using DMatrix
optimized_params = random_search.best_params_.copy()

# Convert parameters for xgb.train()
optimized_params['eta'] = optimized_params.pop('learning_rate')
optimized_params['objective'] = 'binary:logistic'
optimized_params['eval_metric'] = 'logloss'

print("\nTraining optimized XGBoost model with best parameters...")
optimized_model = xgb.train(
    optimized_params,
    dtrain,
    num_boost_round=optimized_params.pop('n_estimators'),
    evals=[(dtrain, 'train'), (dtest, 'eval')],
    # early_stopping_rounds=20,
    # verbose_eval=20
)
# Out:
# Training optimized XGBoost model with best parameters...
# [0]	train-logloss:0.69255	eval-logloss:0.69252
# [1]	train-logloss:0.69196	eval-logloss:0.69213
# [2]	train-logloss:0.69142	eval-logloss:0.69184
# [3]	train-logloss:0.69087	eval-logloss:0.69140
# [4]	train-logloss:0.69032	eval-logloss:0.69074
# [5]	train-logloss:0.68974	eval-logloss:0.69036
# [6]	train-logloss:0.68920	eval-logloss:0.68983
# [7]	train-logloss:0.68873	eval-logloss:0.68946
# [8]	train-logloss:0.68816	eval-logloss:0.68919
# [9]	train-logloss:0.68763	eval-logloss:0.68874
# [10]	train-logloss:0.68714	eval-logloss:0.68814
# [11]	train-logloss:0.68660	eval-logloss:0.68781
# [12]	train-logloss:0.68618	eval-logloss:0.68762
# [13]	train-logloss:0.68566	eval-logloss:0.68728
# [14]	train-logloss:0.68527	eval-logloss:0.68715
# [15]	train-logloss:0.68486	eval-logloss:0.68691
# [16]	train-logloss:0.68439	eval-logloss:0.68642
# [17]	train-logloss:0.68400	eval-logloss:0.68600
# [18]	train-logloss:0.68363	eval-logloss:0.68569
# [19]	train-logloss:0.68324	eval-logloss:0.68551
# [20]	train-logloss:0.68276	eval-logloss:0.68525
# [21]	train-logloss:0.68243	eval-logloss:0.68501
# [22]	train-logloss:0.68199	eval-logloss:0.68428
# [23]	train-logloss:0.68154	eval-logloss:0.68374
# [24]	train-logloss:0.68110	eval-logloss:0.68348
# [25]	train-logloss:0.68078	eval-logloss:0.68331
# [26]	train-logloss:0.68049	eval-logloss:0.68312
# [27]	train-logloss:0.68003	eval-logloss:0.68269
# [28]	train-logloss:0.67975	eval-logloss:0.68290
# [29]	train-logloss:0.67946	eval-logloss:0.68277
# [30]	train-logloss:0.67918	eval-logloss:0.68283
# [31]	train-logloss:0.67878	eval-logloss:0.68256
# [32]	train-logloss:0.67852	eval-logloss:0.68235
# [33]	train-logloss:0.67816	eval-logloss:0.68214
# [34]	train-logloss:0.67782	eval-logloss:0.68172
# [35]	train-logloss:0.67748	eval-logloss:0.68084
# [36]	train-logloss:0.67715	eval-logloss:0.68101
# [37]	train-logloss:0.67684	eval-logloss:0.68084
# [38]	train-logloss:0.67653	eval-logloss:0.68072
# [39]	train-logloss:0.67625	eval-logloss:0.68045
# [40]	train-logloss:0.67600	eval-logloss:0.68026
# [41]	train-logloss:0.67569	eval-logloss:0.68006
# [42]	train-logloss:0.67534	eval-logloss:0.67973
# [43]	train-logloss:0.67511	eval-logloss:0.67950
# [44]	train-logloss:0.67479	eval-logloss:0.67893
# [45]	train-logloss:0.67443	eval-logloss:0.67866
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down (0)', 'Up (1)'])
disp.plot(cmap='Blues')
plt.title('Optimized Model Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
# Print classification report
print("\n Optimized Model Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#  Optimized Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.24      0.65      0.35       170
#            1       0.89      0.58      0.70       844
#
#     accuracy                           0.59      1014
#    macro avg       0.56      0.61      0.52      1014
# weighted avg       0.78      0.59      0.64      1014

# %%
# ROC Curve - Optimized Model
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

disp = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
disp.plot()

plt.title('Optimized Model ROC Curve')
plt.plot([0, 1], [0, 1], color='orange', lw=2, linestyle='--')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Calculate training accuracy
train_preds = np.round(optimized_model.predict(dtrain))
train_accuracy = accuracy_score(y_train, train_preds)

# Calculate test accuracy
test_preds = np.round(optimized_model.predict(dtest))
test_accuracy = accuracy_score(y_test, test_preds)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Difference (Training - Test): {train_accuracy - test_accuracy:.4f}")
# Out:
# Training Accuracy: 0.6297
# Test Accuracy: 0.5888
# Difference (Training - Test): 0.0409

# %% [markdown]
# **OPTIONAL - EXAMPLE - Save Model**

# %%
# Save the optimized model - XGBoost's native format
optimized_model.save_model('ks_xgboost_model.json')
print("\nOptimized model saved as 'ks_xgboost_model.json'")
# Out:
# Optimized model saved as 'ks_xgboost_model.json'

# %% [markdown]
# **OPTIONAL - EXAMPLE - Load Model**

# %%
# OPTIONAL
# Example of loading the model
# loaded_model = xgb.Booster()
# loaded_model.load_model('ks_xgboost_model.json')
# predictions = loaded_model.predict(dtest)

# %% [markdown]
# ### Feature Importance
#
# Feature Importance refers to techniques that calculate a score for all the input features for a given model where the scores represent the “importance” of each feature. It is calculated as the decrease in node impurity weighted by the probability of reaching that node. The node probability can be calculated by the number of samples that reach the node, divided by the total number of samples. The higher the value the more important the feature.
#
# The Gain is the most relevant attribute to interpret the relative importance of each feature.

# %%
# Plot the feature importance of the optimized model
plot_importance(optimized_model, importance_type='gain', title='Optimized Model Feature Importance', show_values=False)
plt.tight_layout()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Plot Tree

# %%
## Tree Visualization
# change tree number to see the corresponding plot
dot = xgb.to_graphviz(optimized_model, num_trees=0, rankdir='TB')
graph = graphviz.Source(dot.source)  # Use .source attribute
graph.view()
# Out:
# 'Source.gv.pdf'

# %% [markdown]
# ## References
#
#
# * [Cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html)
# * [TimeSeriesSplit](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html)
# * [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
# * [Hyperparameters Tuning](https://scikit-learn.org/stable/modules/grid_search.html#grid-search)
# * [Metrics & Scoring](https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter)
# * [Introduction to Boosted Trees](https://xgboost.readthedocs.io/en/latest/tutorials/model.html)
# * [XGBoost documentation](https://xgboost.readthedocs.io/en/latest/index.html)
# * [XGBoost (clone) documentation](https://xgboost-clone.readthedocs.io/en/latest/python/python_intro.html)

# %% [markdown]
# ---
# Python Labs by [Kannan Singaravelu](https://www.linkedin.com/in/kannansi)
